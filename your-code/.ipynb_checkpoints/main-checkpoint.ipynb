# %% [markdown]
# # Supervised Learning Model Evaluation Lab
#
# Complete the exercises below to solidify your knowledge and understanding of supervised learning model evaluation.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split as tts
from sklearn.linear_model import LinearRegression as LinReg 
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error as mae
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score as acc
from sklearn.metrics import precision_score as prec
from sklearn.metrics import recall_score as rec
from sklearn.metrics import f1_score as f1
from sklearn.metrics import confusion_matrix as cm
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ## Regression Model Evaluation

# %%
from sklearn.datasets import fetch_california_housing

data = fetch_california_housing()

X = pd.DataFrame(data.data, columns=data.feature_names)

y = pd.DataFrame(data.target, columns=['MedHouseVal'])

data = pd.concat([X, y], axis=1)

# %% [markdown]
# ## 1. Split this data set into training (80%) and testing (20%) sets.
#
# The `MEDV` field represents the median value of owner-occupied homes (in $1000's) and is the target variable that we will want to predict.

# %%
X_train, X_test, y_train, y_test = tts(X, y, test_size=0.2, random_state=42)

# %% [markdown]
# ## 2. Train a `LinearRegression` model on this data set and generate predictions on both the training and the testing set.

# %%
linreg=LinReg()

# %%
linreg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## 3. Calculate and print R-squared for both the training and the testing set.

# %%
y_train_pred = linreg.predict(X_train)
y_test_pred = linreg.predict(X_test)

r_train = r2_score(y_train, y_train_pred)
r_test = r2_score(y_test, y_test_pred)

r_train, r_test
# Out:
# (0.6125511913966952, 0.5757877060324512)

# %% [markdown]
# ## 4. Calculate and print mean squared error for both the training and the testing set.

# %%
mse_train = mean_squared_error(y_train, y_train_pred)
mse_test = mean_squared_error(y_test, y_test_pred)

mse_train, mse_test
# Out:
# (0.5179331255246699, 0.5558915986952438)

# %% [markdown]
# ## 5. Calculate and print mean absolute error for both the training and the testing set.

# %%
mae_train = mae(y_train, y_train_pred)
mae_test = mae(y_test, y_test_pred)

mae_train, mae_test
# Out:
# (0.5286283596581932, 0.5332001304956564)

# %% [markdown]
# ## Classification Model Evaluation

# %%
from sklearn.datasets import load_iris

data = load_iris()

X = pd.DataFrame(data["data"], columns=data["feature_names"])
y = pd.DataFrame(data["target"], columns=["class"])

data = pd.concat([X, y], axis=1)

# %% [markdown]
# ## 6. Split this data set into training (80%) and testing (20%) sets.
#
# The `class` field represents the type of flower and is the target variable that we will want to predict.

# %%
X_train, X_test, y_train, y_test = tts(X, y, test_size=0.2, random_state=42)

# %% [markdown]
# ## 7. Train a `LogisticRegression` model on this data set and generate predictions on both the training and the testing set.

# %%
log=LogisticRegression()
log.fit(X_train, y_train)
# Out:
# C:\Users\akoun\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %% [markdown]
# ## 8. Calculate and print the accuracy score for both the training and the testing set.

# %%
y_test_pred = log.predict(X_test)  
y_train_pred = log.predict(X_train)
acc(y_test, y_test_pred), acc(y_train, y_train_pred)
# Out:
# (1.0, 0.975)

# %% [markdown]
# ## 9. Calculate and print the balanced accuracy score for both the training and the testing set.

# %%
#TO IGNORE

# %% [markdown]
# ## 10. Calculate and print the precision score for both the training and the testing set.

# %%
#added average='micro' since it was giving me a lot of errors 
prec(y_test, y_test_pred, average='micro'), prec(y_train, y_train_pred, average='micro')
# Out:
# (1.0, 0.975)

# %% [markdown]
# ## 11. Calculate and print the recall score for both the training and the testing set.

# %%
rec(y_test, y_test_pred, average='micro'), rec(y_train, y_train_pred, average='micro')
# Out:
# (1.0, 0.975)

# %% [markdown]
# ## 12. Calculate and print the F1 score for both the training and the testing set.

# %%
f1(y_test, y_test_pred, average='micro'), f1(y_train, y_train_pred, average='micro')
# Out:
# (1.0, 0.975)

# %% [markdown]
# ## 13. Generate confusion matrices for both the training and the testing set.

# %%
cm(y_test, y_test_pred)
plt.figure(figsize=(15, 8))

ax=sns.heatmap(cm(y_test, y_test_pred)/cm(y_test, y_test_pred).sum(), annot=True)

plt.title('Matriz confusion')
plt.ylabel('Verdad')
plt.xlabel('Prediccion')
plt.show();

# %%
cm(y_train, y_train_pred)
plt.figure(figsize=(15, 8))

ax=sns.heatmap(cm(y_train, y_train_pred)/cm(y_train, y_train_pred).sum(), annot=True)

plt.title('Matriz confusion')
plt.ylabel('Verdad')
plt.xlabel('Prediccion')
plt.show();

# %% [markdown]
# ## Bonus: For each of the data sets in this lab, try training with some of the other models you have learned about, recalculate the evaluation metrics, and compare to determine which models perform best on each data set.
